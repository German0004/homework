# %% [markdown]
# https://realpython.com/python-concurrency/

# %%
print("Лекція 5: потоки, процеси та асинхронність у Python")
# Out:
# Лекція 5: потоки, процеси та асинхронність у Python

# %% [markdown]
# ## Concurrency (паралелізм) у Python
#
# ---
#
# ![тематична заставка](./media/parallel_computing.jpg)
#
#
# Що робить програма, поки чекає відповіді від сервера або чекає, поки файл прочитається з жорсткого диска? Зазвичай у такі моменти застосунок нічого не робить та просто чекає на результат операції. Це не є проблемою, якщо не потрібно прискорити роботу програми. Особливо це критично для ситуацій, коли програма робить багато дуже схожих блокуючих викликів (запитів на віддалений сервер, операцій читання/запису файлів). У такі моменти хочеться оптимізувати роботу програми та виконувати кілька операцій, що блокують, паралельно. Код, який виконує паралельно кілька завдань, називається асинхронним. Найпростіший спосіб реалізувати асинхронність — це виконувати завдання в окремих потоках всередині одного процесу.
#
# __Процес__ — область пам'яті (віртуальна) + набір ресурсів + 1 та більше потоків.
#
# __Потік__ — послідовність інструкцій та системних викликів усередині процесу.
#
# Усі потоки мають доступом до всіх ресурсів свого процесу. Всі процеси ізольовані один від одного та будь-яка міжпроцесна взаємодія відбувається лише через операції введення/виводу (системні виклики).
#
# Завдання, які виконують операції введення/виводу (читання/запис файлів, запити в мережі тощо), називаються IO (Input Output)-bound завданнями. Досягти паралелізму виконання IO завдань у Python можна, використовуючи потоки.
#
# Однак треба пам'ятати, що асинхронний код завжди на порядок складніше для розуміння та налагодження. Для багатопотокових застосунків складно писати тести та складно перевіряти всілякі ситуації, які відбуваються рідко та залежать від порядку викликів у різних потоках. Загальне правило для програмування будь-якою мовою: якщо є можливість обійтися синхронним кодом, то треба таким чином зробити.
#
# Інший тип блокуючих викликів — це важкі з погляду обчислень операції. Реальна програма завжди повинна якось відгукуватися на дії користувача та якщо ваша програма під час виконання складних обчислень перестає відповідати на запити, то користувач може вирішити, що програма просто зависла. Виходить, що для зручності користувача програма повинна відповідати на запити, навіть коли робить якісь складні та довгі обчислення.
#
# Такі завдання називаються CPU-bound задачами. Як й для IO-bound завдань можна винести виконання блокуючих операцій (складних обчислень) до окремого потоку, щоб програма продовжувала взаємодіяти з користувачем, проводячи обчислення.
#
# Потокам управління передає операційна система (як й передача управління процесам). Це означає, що у будь-який момент перед будь-яким викликом ОС (Операційна Система) може призупинити виконання коду потоку та почати виконувати код іншого потоку, щоб потім точно так само призупинити та його для передачі управління далі.
#
# До появи багатоядерних процесорів справжній паралелізм був неможливим. Звичайно, коли керування передається різним потокам по кілька тисяч разів на секунду, з погляду користувача це виглядає як паралельне виконання кількох завдань. У сучасних процесорах зазвичай є щонайменше два ядра та тепер ми можемо писати код, який виконується дійсно паралельно. Це з одного боку додає можливостей, але й додає складнощів, оскільки тепер треба бути ще уважнішими при написанні асинхронного коду, адже припуститися помилки ще простіше.
#
#
# Паралелізм (у контексті мов програмування) означає одночасне виникнення. У Python речі, які відбуваються одночасно, називаються різними іменами (потік, завдання, процес), але на високому рівні всі вони посилаються на послідовність інструкцій, які виконуються по черзі.
#
# Таким чином, до "одночасного" виконання відносять декілька понять:
# - thread (потік);
# - task (завдання);
# - process (процес).
#
# Можe здаватися дивним, чому Python використовує різні слова для того самого поняття. Виявляється, потоки, завдання та процеси однакові, лише якщо розглядати їх з високого рівня. Коли починається занурення до деталей, усі вони представляють насправді різні речі. У міру проходження прикладів побачите, чим вони відрізняються.
#
#
# Важливо розуміти, що коли використовуємо слова "одночасне виконання", то когнітивно ми міркуємо саме про ОДНОЧАСНЕ виконання. Але для потоків (thread) та завдань (task у розумінні асинхронного програмування) це не так. Вони працюють на одному процесорі, тому працюють лише по одному в один момент. Просто вони вміють працювати так, що це дозволяє пришвидшити загальний час виконання програми. Водночас, вони не використовують паралельні обчислення, проте все одно їх називать паралельними.

# %% [markdown]
# ### Як працює багатозадачність у операційних системах.
#
# Докладно — [тут](https://uk.wikipedia.org/wiki/%D0%91%D0%B0%D0%B3%D0%B0%D1%82%D0%BE%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%D0%BD%D1%96%D1%81%D1%82%D1%8C#:~:text=%D0%A1%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D0%B0%20%D0%BE%D1%80%D0%B3%D0%B0%D0%BD%D1%96%D0%B7%D0%BE%D0%B2%D1%83%D1%94%20%D1%87%D0%B5%D1%80%D0%B3%D0%B8%20%D0%B7%D0%B0%D0%B2%D0%B4%D0%B0%D0%BD%D1%8C%20%D1%82%D0%B0%D0%BA,%D0%BC%D0%BE%D0%B6%D1%83%D1%82%D1%8C%20%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D1%83%D0%B2%D0%B0%D1%82%D0%B8%D1%81%D1%8F%2C%20%D0%B4%D0%B5%D0%B0%D0%BA%D1%82%D0%B8%D0%B2%D1%83%D0%B2%D0%B0%D1%82%D0%B8%D1%81%D1%8F%20%D1%96%20%D0%B2%D1%96%D0%B4%D0%B4%D0%B0%D0%BB%D1%8F%D1%82%D0%B8%D1%81%D1%8F).
#
# Будемо звертати увагу тільки на ті моменти, які необхідні у рамках розуміння основної теми заняття.
#
# Один з методів реалізації багатозадачності — витискальна багатозадачність. Докладніше — [тут](https://uk.wikipedia.org/wiki/%D0%92%D0%B8%D1%82%D0%B8%D1%81%D0%BA%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0_%D0%B1%D0%B0%D0%B3%D0%B0%D1%82%D0%BE%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%D0%BD%D1%96%D1%81%D1%82%D1%8C).
#
# Суть її дуже проста. Операційна система в один момент часу обробляє лише одне завдання та дуже швидко перемикається між різними завданнями.
#
# ![витісняюча багатозадачність](./media/mulitask.png)

# %% [markdown]
#  Витісняюча баготозадачність буває випереджаюча та кооперативною.
#
#  Випереджаюча багатозадачність зручна тим, що коду в потоці не потрібно нічого робити, щоб здійснити перемикання. Також це може бути важко через фразу «будь-коли». Це перемикання може статися в середині одного оператора Python, навіть такого тривіального, як x = x + 1. Це те, як працюють потоки — threading.
#
# Asyncio, з іншого боку, використовує кооперативну багатозадачність. Завдання повинні співпрацювати, оголошуючи, коли вони готові до вимкнення. Це означає, що код завдання має трохи змінитися, щоб це сталося.
#
# Перевага виконання цієї додаткової роботи наперед полягає у тому, що ви завжди знаєте, куди ваше завдання буде замінено. Його не буде замінено в середині оператора Python, якщо цей оператор не позначено. Пізніше побачите, як це може спростити частини вашого дизайну.

# %% [markdown]
# ## IO-bound: порівняємо різні підходи до вирішення.
#
# Порівняємо використання різних підходів до вирішення одного та того ж класичного IO-bound — завантаженні вмісту через мережу. У нашому прикладі ми будемо завантажувати веб-сторінки з кількох сайтів, але насправді це може бути будь-який мережевий трафік. Це просто легше візуалізувати та налаштувати за допомогою веб-сторінок.
#
#
# #### Синхронна версія.

# %%
import requests
import functools
import time


def get_duration(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        duration = time.time() - start_time
        print(f"Duration = {duration}")
        return res

    return wrapper


def download_site(url, session, count):
    with session.get(url) as response:
        print(f"{count} --> Read {len(response.content)} from {url}")


@get_duration
def download_all_sites(sites):
    with requests.Session() as session:
        for count, url in enumerate(sites):
            download_site(url, session, count)


sites = [
            "http://www.testingmcafeesites.com/index.html",
            "https://www.jython.org"
        ] * 200

# %% [markdown]
# Як бачимо, це досить коротка програма.
#
# get_duration() — простий декоратор, який допоможе визначати час виконання нашого коду. Він друкує, скільки часу тривав цей процес, щоб ви могли отримати задоволення від того, наскільки нам допоміг паралелізм у наступних прикладах.
#
# Функція download_site() — просто завантажує вміст з URL-адреси та друкує розмір. Слід зазначити одну незначну річ: у прикладі використовується Session об’єкт з модуля requests. Можна просто використовувати напряму get() з requests, але створення Session об’єкта дозволяє requests виконувати деякі хитрощі мережевих трюків та дійсно пришвидшити роботу.
#
# Функція download_all_sites() створює Session, а потім переглядає список сайтів, завантажуючи кожен з них по черзі. Вбудовану функцію enumerate використовується для того, щоб побачити послідовність виконання запитів до сайтів.
#
# Запустіть код нижче (не забувайте перед цим виконати усі попередні блоки коду).

# %%
a = download_all_sites(sites)
# Out:
# 0 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 1 --> Read 10782 from https://www.jython.org
# 2 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 3 --> Read 10782 from https://www.jython.org
# 4 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 5 --> Read 10782 from https://www.jython.org
# 6 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 7 --> Read 10782 from https://www.jython.org
# 8 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 9 --> Read 10782 from https://www.jython.org
# 10 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 11 --> Read 10782 from https://www.jython.org
# 12 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 13 --> Read 10782 from https://www.jython.org
# 14 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 15 --> Read 10782 from https://www.jython.org
# 16 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 17 --> Read 10782 from https://www.jython.org
# 18 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 19 --> Read 10782 from https://www.jython.org
# 20 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 21 --> Read 10782 from https://www.jython.org
# 22 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 23 --> Read 10782 from https://www.jython.org
# 24 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 25 --> Read 10782 from https://www.jython.org
# 26 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 27 --> Read 10782 from https://www.jython.org
# 28 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 29 --> Read 10782 from https://www.jython.org
# 30 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 31 --> Read 10782 from https://www.jython.org
# 32 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 33 --> Read 10782 from https://www.jython.org
# 34 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 35 --> Read 10782 from https://www.jython.org
# 36 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 37 --> Read 10782 from https://www.jython.org
# 38 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 39 --> Read 10782 from https://www.jython.org
# 40 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 41 --> Read 10782 from https://www.jython.org
# 42 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 43 --> Read 10782 from https://www.jython.org
# 44 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 45 --> Read 10782 from https://www.jython.org
# 46 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 47 --> Read 10782 from https://www.jython.org
# 48 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 49 --> Read 10782 from https://www.jython.org
# 50 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 51 --> Read 10782 from https://www.jython.org
# 52 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 53 --> Read 10782 from https://www.jython.org
# 54 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 55 --> Read 10782 from https://www.jython.org
# 56 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 57 --> Read 10782 from https://www.jython.org
# 58 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 59 --> Read 10782 from https://www.jython.org
# 60 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 61 --> Read 10782 from https://www.jython.org
# 62 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 63 --> Read 10782 from https://www.jython.org
# 64 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 65 --> Read 10782 from https://www.jython.org
# 66 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 67 --> Read 10782 from https://www.jython.org
# 68 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 69 --> Read 10782 from https://www.jython.org
# 70 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 71 --> Read 10782 from https://www.jython.org
# 72 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 73 --> Read 10782 from https://www.jython.org
# 74 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 75 --> Read 10782 from https://www.jython.org
# 76 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 77 --> Read 10782 from https://www.jython.org
# 78 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 79 --> Read 10782 from https://www.jython.org
# 80 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 81 --> Read 10782 from https://www.jython.org
# 82 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 83 --> Read 10782 from https://www.jython.org
# 84 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 85 --> Read 10782 from https://www.jython.org
# 86 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 87 --> Read 10782 from https://www.jython.org
# 88 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 89 --> Read 10782 from https://www.jython.org
# 90 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 91 --> Read 10782 from https://www.jython.org
# 92 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 93 --> Read 10782 from https://www.jython.org
# 94 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 95 --> Read 10782 from https://www.jython.org
# 96 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 97 --> Read 10782 from https://www.jython.org
# 98 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 99 --> Read 10782 from https://www.jython.org
# 100 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 101 --> Read 10782 from https://www.jython.org
# 102 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 103 --> Read 10782 from https://www.jython.org
# 104 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 105 --> Read 10782 from https://www.jython.org
# 106 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 107 --> Read 10782 from https://www.jython.org
# 108 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 109 --> Read 10782 from https://www.jython.org
# 110 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 111 --> Read 10782 from https://www.jython.org
# 112 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 113 --> Read 10782 from https://www.jython.org
# 114 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 115 --> Read 10782 from https://www.jython.org
# 116 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 117 --> Read 10782 from https://www.jython.org
# 118 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 119 --> Read 10782 from https://www.jython.org
# 120 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 121 --> Read 10782 from https://www.jython.org
# 122 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 123 --> Read 10782 from https://www.jython.org
# 124 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 125 --> Read 10782 from https://www.jython.org
# 126 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 127 --> Read 10782 from https://www.jython.org
# 128 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 129 --> Read 10782 from https://www.jython.org
# 130 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 131 --> Read 10782 from https://www.jython.org
# 132 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 133 --> Read 10782 from https://www.jython.org
# 134 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 135 --> Read 10782 from https://www.jython.org
# 136 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 137 --> Read 10782 from https://www.jython.org
# 138 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 139 --> Read 10782 from https://www.jython.org
# 140 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 141 --> Read 10782 from https://www.jython.org
# 142 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 143 --> Read 10782 from https://www.jython.org
# 144 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 145 --> Read 10782 from https://www.jython.org
# 146 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 147 --> Read 10782 from https://www.jython.org
# 148 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 149 --> Read 10782 from https://www.jython.org
# 150 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 151 --> Read 10782 from https://www.jython.org
# 152 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 153 --> Read 10782 from https://www.jython.org
# 154 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 155 --> Read 10782 from https://www.jython.org
# 156 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 157 --> Read 10782 from https://www.jython.org
# 158 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 159 --> Read 10782 from https://www.jython.org
# 160 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 161 --> Read 10782 from https://www.jython.org
# 162 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 163 --> Read 10782 from https://www.jython.org
# 164 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 165 --> Read 10782 from https://www.jython.org
# 166 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 167 --> Read 10782 from https://www.jython.org
# 168 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 169 --> Read 10782 from https://www.jython.org
# 170 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 171 --> Read 10782 from https://www.jython.org
# 172 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 173 --> Read 10782 from https://www.jython.org
# 174 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 175 --> Read 10782 from https://www.jython.org
# 176 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 177 --> Read 10782 from https://www.jython.org
# 178 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 179 --> Read 10782 from https://www.jython.org
# 180 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 181 --> Read 10782 from https://www.jython.org
# 182 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 183 --> Read 10782 from https://www.jython.org
# 184 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 185 --> Read 10782 from https://www.jython.org
# 186 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 187 --> Read 10782 from https://www.jython.org
# 188 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 189 --> Read 10782 from https://www.jython.org
# 190 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 191 --> Read 10782 from https://www.jython.org
# 192 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 193 --> Read 10782 from https://www.jython.org
# 194 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 195 --> Read 10782 from https://www.jython.org
# 196 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 197 --> Read 10782 from https://www.jython.org
# 198 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 199 --> Read 10782 from https://www.jython.org
# 200 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 201 --> Read 10782 from https://www.jython.org
# 202 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 203 --> Read 10782 from https://www.jython.org
# 204 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 205 --> Read 10782 from https://www.jython.org
# 206 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 207 --> Read 10782 from https://www.jython.org
# 208 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 209 --> Read 10782 from https://www.jython.org
# 210 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 211 --> Read 10782 from https://www.jython.org
# 212 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 213 --> Read 10782 from https://www.jython.org
# 214 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 215 --> Read 10782 from https://www.jython.org
# 216 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 217 --> Read 10782 from https://www.jython.org
# 218 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 219 --> Read 10782 from https://www.jython.org
# 220 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 221 --> Read 10782 from https://www.jython.org
# 222 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 223 --> Read 10782 from https://www.jython.org
# 224 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 225 --> Read 10782 from https://www.jython.org
# 226 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 227 --> Read 10782 from https://www.jython.org
# 228 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 229 --> Read 10782 from https://www.jython.org
# 230 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 231 --> Read 10782 from https://www.jython.org
# 232 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 233 --> Read 10782 from https://www.jython.org
# 234 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 235 --> Read 10782 from https://www.jython.org
# 236 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 237 --> Read 10782 from https://www.jython.org
# 238 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 239 --> Read 10782 from https://www.jython.org
# 240 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 241 --> Read 10782 from https://www.jython.org
# 242 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 243 --> Read 10782 from https://www.jython.org
# 244 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 245 --> Read 10782 from https://www.jython.org
# 246 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 247 --> Read 10782 from https://www.jython.org
# 248 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 249 --> Read 10782 from https://www.jython.org
# 250 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 251 --> Read 10782 from https://www.jython.org
# 252 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 253 --> Read 10782 from https://www.jython.org
# 254 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 255 --> Read 10782 from https://www.jython.org
# 256 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 257 --> Read 10782 from https://www.jython.org
# 258 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 259 --> Read 10782 from https://www.jython.org
# 260 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 261 --> Read 10782 from https://www.jython.org
# 262 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 263 --> Read 10782 from https://www.jython.org
# 264 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 265 --> Read 10782 from https://www.jython.org
# 266 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 267 --> Read 10782 from https://www.jython.org
# 268 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 269 --> Read 10782 from https://www.jython.org
# 270 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 271 --> Read 10782 from https://www.jython.org
# 272 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 273 --> Read 10782 from https://www.jython.org
# 274 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 275 --> Read 10782 from https://www.jython.org
# 276 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 277 --> Read 10782 from https://www.jython.org
# 278 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 279 --> Read 10782 from https://www.jython.org
# 280 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 281 --> Read 10782 from https://www.jython.org
# 282 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 283 --> Read 10782 from https://www.jython.org
# 284 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 285 --> Read 10782 from https://www.jython.org
# 286 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 287 --> Read 10782 from https://www.jython.org
# 288 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 289 --> Read 10782 from https://www.jython.org
# 290 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 291 --> Read 10782 from https://www.jython.org
# 292 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 293 --> Read 10782 from https://www.jython.org
# 294 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 295 --> Read 10782 from https://www.jython.org
# 296 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 297 --> Read 10782 from https://www.jython.org
# 298 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 299 --> Read 10782 from https://www.jython.org
# 300 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 301 --> Read 10782 from https://www.jython.org
# 302 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 303 --> Read 10782 from https://www.jython.org
# 304 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 305 --> Read 10782 from https://www.jython.org
# 306 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 307 --> Read 10782 from https://www.jython.org
# 308 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 309 --> Read 10782 from https://www.jython.org
# 310 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 311 --> Read 10782 from https://www.jython.org
# 312 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 313 --> Read 10782 from https://www.jython.org
# 314 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 315 --> Read 10782 from https://www.jython.org
# 316 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 317 --> Read 10782 from https://www.jython.org
# 318 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 319 --> Read 10782 from https://www.jython.org
# 320 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 321 --> Read 10782 from https://www.jython.org
# 322 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 323 --> Read 10782 from https://www.jython.org
# 324 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 325 --> Read 10782 from https://www.jython.org
# 326 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 327 --> Read 10782 from https://www.jython.org
# 328 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 329 --> Read 10782 from https://www.jython.org
# 330 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 331 --> Read 10782 from https://www.jython.org
# 332 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 333 --> Read 10782 from https://www.jython.org
# 334 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 335 --> Read 10782 from https://www.jython.org
# 336 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 337 --> Read 10782 from https://www.jython.org
# 338 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 339 --> Read 10782 from https://www.jython.org
# 340 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 341 --> Read 10782 from https://www.jython.org
# 342 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 343 --> Read 10782 from https://www.jython.org
# 344 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 345 --> Read 10782 from https://www.jython.org
# 346 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 347 --> Read 10782 from https://www.jython.org
# 348 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 349 --> Read 10782 from https://www.jython.org
# 350 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 351 --> Read 10782 from https://www.jython.org
# 352 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 353 --> Read 10782 from https://www.jython.org
# 354 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 355 --> Read 10782 from https://www.jython.org
# 356 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 357 --> Read 10782 from https://www.jython.org
# 358 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 359 --> Read 10782 from https://www.jython.org
# 360 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 361 --> Read 10782 from https://www.jython.org
# 362 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 363 --> Read 10782 from https://www.jython.org
# 364 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 365 --> Read 10782 from https://www.jython.org
# 366 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 367 --> Read 10782 from https://www.jython.org
# 368 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 369 --> Read 10782 from https://www.jython.org
# 370 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 371 --> Read 10782 from https://www.jython.org
# 372 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 373 --> Read 10782 from https://www.jython.org
# 374 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 375 --> Read 10782 from https://www.jython.org
# 376 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 377 --> Read 10782 from https://www.jython.org
# 378 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 379 --> Read 10782 from https://www.jython.org
# 380 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 381 --> Read 10782 from https://www.jython.org
# 382 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 383 --> Read 10782 from https://www.jython.org
# 384 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 385 --> Read 10782 from https://www.jython.org
# 386 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 387 --> Read 10782 from https://www.jython.org
# 388 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 389 --> Read 10782 from https://www.jython.org
# 390 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 391 --> Read 10782 from https://www.jython.org
# 392 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 393 --> Read 10782 from https://www.jython.org
# 394 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 395 --> Read 10782 from https://www.jython.org
# 396 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 397 --> Read 10782 from https://www.jython.org
# 398 --> Read 28634 from http://www.testingmcafeesites.com/index.html
# 399 --> Read 10782 from https://www.jython.org
# Duration = 62.253541231155396

# %% [markdown]
# Синхронна версія працює. Запам'ятайте час, на протязі якого тривало виконання цього блоку коду.
# Ця версія коду проста у написанні, проста у налагоджуванні та у виконанні. Але, як побачимо далі, це буде найповільніший варіант.
#
# Однак бути повільнішим не завжди є великою проблемою. Якщо програма, яку ви запускаєте, займає лише 2 секунди з синхронною версією та запускається рідко, можливо, не варто додавати паралелізм. Зупинимося тут детальніше.
#
# Діаграма обробки для цієї програми буде виглядати наступним чином:
#
# ![синхронна версія, діаграма роботи](media/IO_bound_task.png)

# %% [markdown]
# #### Потоки. Threading-версія.
#
# Написання потокової програми вимагає більше зусиль. Однак ви можете бути здивовані тим, як мало додаткових зусиль потрібно для простих випадків. Ось як виглядає та сама програма з threading:

# %%
import concurrent.futures
import requests
import threading
import time

thread_local = threading.local()


def get_duration(func):
    @functools.wraps(func)
    def wraper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        duration = time.time() - start_time
        print(f"Duration = {duration}")
        return res

    return wraper


def get_session():
    if not hasattr(thread_local, "session"):
        thread_local.session = requests.Session()
    return thread_local.session


def download_site(site_num):
    session = get_session()
    with session.get(site_num[1]) as response:
        print(f"{site_num[0]}: read {len(response.content)} from {site_num[1]}")


@get_duration
def download_all_sites(sites):
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
        executor.map(download_site, sites)


sites = [
            "http://www.testingmcafeesites.com/index.html",
            "https://www.jython.org"
        ] * 200

sites_num = [(num, site) for num, site in enumerate(sites)]

# %% [markdown]
# При додаванні потоків, загальна структура залишається тією самою та потрібно лише внести кілька змін.
#
# Функцію download_all_sites() змінено від виклику функції один раз для сайту до більш складної структури.
#
# У цій версії ми створюємо інстанс класу ThreadPoolExecutor, що здається складною річчю. Розглянемо це детальніше:
#
# ThreadPoolExecutor = Thread + Pool + Executor.
#
# Thread частина — це лише потік, який ми згадували раніше.
#
# Далі – Pool. Це те, де починає ставати цікавим. Цей об’єкт збирається створити пул потоків (деяку кількість), кожен з яких може працювати одночасно. Нарешті, Executor це та частина, яка контролюватиме, як та коли кожен з потоків у пулі буде працювати. Він виконає запит у пулі.
#
# До речі, стандартна бібліотека реалізує клас ThreadPoolExecutor як менеджер контексту, щоб ви могли використовувати with синтаксис для керування створенням та звільненням пулу Threads.
#
# Маючи ThreadPoolExecutor, можна використовувати його зручний метод .map(). Цей метод запускає передану функцію на кожному з сайтів у списку. Головне, що він автоматично запускає їх одночасно, використовуючи пул потоків, якими він керує.
#
# У Python є досить велика кількість функціоналу, який керує деталями. У модулі threading є такі інструменти як Thread.start(), Thread.join() та Queue.
#
# Усе це все ще є й ви можете використовувати їх для досягнення точного контролю над тим, як виконуються ваші потоки. Але, починаючи з Python 3.2, стандартна бібліотека додала абстракцію вищого рівня під назвою Executors, яка керує багатьма деталями за вас, якщо вам не потрібен цей тонкий контроль, який ми й використовуємо зараз.
#
# Ще одна цікава зміна у нашому прикладі полягає в тому, що кожен потік повинен створити свій власний об’єкт requests.Session(). Коли ви переглядаєте документацію для requests, це не обов’язково легко зрозуміти, але читаючи цю проблему, здається досить очевидним, що потрібен окремий сеанс для кожного потоку.
#
# Це одне з цікавих й складних питань з threading. Оскільки операційна система контролює, коли ваше завдання переривається та починається інше завдання, будь-які дані, якими спільно користуються потоки, мають бути захищені або безпечні для потоків. На жаль, requests.Session(), це потоконебезпечний.
#
# Існує кілька стратегій потокобезпечного доступу до даних залежно від того, які дані та як ви їх використовуєте. Одним з них є використання потокобезпечних структур даних, як Queue з queue модуля Python.
#
# Ці об’єкти використовують низькорівневі примітиви, threading.Lock, щоб гарантувати, що лише один потік може отримати доступ до блоку коду або частини пам’яті одночасно. Ви використовуєте цю стратегію опосередковано через об’єкт ThreadPoolExecutor.
#
# Ще одна стратегія, яку тут можна використовувати, — це локальне зберігання потоків. threading.local() створює об’єкт, який виглядає як глобальний, але специфічний для кожного окремого потоку. У вашому прикладі це робиться за допомогою thread_local та get_session():
#
# local() є у складі threading модуля, щоб конкретно вирішити цю проблему. Це виглядає трохи дивно, але ви хочете створити лише один з цих об’єктів, а не по одному для кожного потоку. Сам об’єкт піклується про розділення доступу з різних потоків до різних даних.
#
# Коли get_session() викликається, session пошук залежить від конкретного потоку, у якому він працює. Таким чином, кожен потік створить окремий сеанс під час першого виклику get_session(), а потім просто використовуватиме цей сеанс під час кожного наступного виклику протягом усього часу існування.
#
# Нарешті, коротке зауваження щодо вибору кількості потоків. Ми бачимо, що приклад коду використовує 5 потоків. Поексперементуйте з цим числом та подивитися, як зміниться загальний час. Можна очікувати, що один потік на кожне завантаження буде найшвидшим (тобто, 400 потоків у нашому випадку), але, принаймні в даних прикладах, це не так. Найшвидші результати десь між 30 та 60 потоками. Якщо піти далі, то додаткові накладні витрати на створення та знищення потоків стирають будь-яку економію часу — при великих кількостях потоків.
#
# Складна відповідь полягає у тому, що правильна кількість потоків не є постійною для кожного завдання. Потрібні деякі експерименти.
#
# Запустіть функцію download_all_sites() та подивіться на час виконання.

# %%
download_all_sites(sites_num)
# Out:
# 7: read 10782 from https://www.jython.org
# 1: read 10782 from https://www.jython.org
# 3: read 10782 from https://www.jython.org
# 13: read 10782 from https://www.jython.org
# 21: read 10782 from https://www.jython.org
# 9: read 10782 from https://www.jython.org
# 5: read 10782 from https://www.jython.org
# 17: read 10782 from https://www.jython.org
# 19: read 10782 from https://www.jython.org
# 15: read 10782 from https://www.jython.org
# 11: read 10782 from https://www.jython.org
# 23: read 10782 from https://www.jython.org
# 25: read 10782 from https://www.jython.org
# 27: read 10782 from https://www.jython.org
# 31: read 10782 from https://www.jython.org
# 6: read 28634 from http://www.testingmcafeesites.com/index.html
# 29: read 10782 from https://www.jython.org
# 0: read 28634 from http://www.testingmcafeesites.com/index.html
# 33: read 10782 from https://www.jython.org
# 18: read 28634 from http://www.testingmcafeesites.com/index.html
# 12: read 28634 from http://www.testingmcafeesites.com/index.html
# 14: read 28634 from http://www.testingmcafeesites.com/index.html
# 2: read 28634 from http://www.testingmcafeesites.com/index.html
# 10: read 28634 from http://www.testingmcafeesites.com/index.html
# 4: read 28634 from http://www.testingmcafeesites.com/index.html
# 8: read 28634 from http://www.testingmcafeesites.com/index.html
# 16: read 28634 from http://www.testingmcafeesites.com/index.html
# 20: read 28634 from http://www.testingmcafeesites.com/index.html
# 22: read 28634 from http://www.testingmcafeesites.com/index.html
# 40: read 28634 from http://www.testingmcafeesites.com/index.html42: read 28634 from http://www.testingmcafeesites.com/index.html
# 47: read 10782 from https://www.jython.org
#
# 24: read 28634 from http://www.testingmcafeesites.com/index.html
# 37: read 10782 from https://www.jython.org
# 26: read 28634 from http://www.testingmcafeesites.com/index.html
# 44: read 28634 from http://www.testingmcafeesites.com/index.html
# 46: read 28634 from http://www.testingmcafeesites.com/index.html
# 28: read 28634 from http://www.testingmcafeesites.com/index.html
# 35: read 10782 from https://www.jython.org
# 30: read 28634 from http://www.testingmcafeesites.com/index.html
# 45: read 10782 from https://www.jython.org
# 41: read 10782 from https://www.jython.org
# 43: read 10782 from https://www.jython.org
# 57: read 10782 from https://www.jython.org
# 32: read 28634 from http://www.testingmcafeesites.com/index.html
# 53: read 10782 from https://www.jython.org
# 59: read 10782 from https://www.jython.org
# 34: read 28634 from http://www.testingmcafeesites.com/index.html
# 39: read 10782 from https://www.jython.org
# 61: read 10782 from https://www.jython.org
# 36: read 28634 from http://www.testingmcafeesites.com/index.html
# 48: read 28634 from http://www.testingmcafeesites.com/index.html
# 63: read 10782 from https://www.jython.org
# 38: read 28634 from http://www.testingmcafeesites.com/index.html
# 69: read 10782 from https://www.jython.org
# 65: read 10782 from https://www.jython.org
# 67: read 10782 from https://www.jython.org
# 71: read 10782 from https://www.jython.org
# 49: read 10782 from https://www.jython.org
# 51: read 10782 from https://www.jython.org
# 50: read 28634 from http://www.testingmcafeesites.com/index.html
# 52: read 28634 from http://www.testingmcafeesites.com/index.html
# 54: read 28634 from http://www.testingmcafeesites.com/index.html
# 56: read 28634 from http://www.testingmcafeesites.com/index.html
# 58: read 28634 from http://www.testingmcafeesites.com/index.html
# 60: read 28634 from http://www.testingmcafeesites.com/index.html
# 77: read 10782 from https://www.jython.org
# 73: read 10782 from https://www.jython.org
# 55: read 10782 from https://www.jython.org
# 75: read 10782 from https://www.jython.org
# 62: read 28634 from http://www.testingmcafeesites.com/index.html
# 79: read 10782 from https://www.jython.org
# 64: read 28634 from http://www.testingmcafeesites.com/index.html
# 66: read 28634 from http://www.testingmcafeesites.com/index.html
# 70: read 28634 from http://www.testingmcafeesites.com/index.html
# 68: read 28634 from http://www.testingmcafeesites.com/index.html
# 81: read 10782 from https://www.jython.org
# 72: read 28634 from http://www.testingmcafeesites.com/index.html
# 85: read 10782 from https://www.jython.org
# 89: read 10782 from https://www.jython.org
# 76: read 28634 from http://www.testingmcafeesites.com/index.html
# 74: read 28634 from http://www.testingmcafeesites.com/index.html
# 87: read 10782 from https://www.jython.org
# 78: read 28634 from http://www.testingmcafeesites.com/index.html
# 91: read 10782 from https://www.jython.org
# 93: read 10782 from https://www.jython.org
# 95: read 10782 from https://www.jython.org
# 97: read 10782 from https://www.jython.org
# 80: read 28634 from http://www.testingmcafeesites.com/index.html
# 82: read 28634 from http://www.testingmcafeesites.com/index.html
# 101: read 10782 from https://www.jython.org
# 99: read 10782 from https://www.jython.org
# 103: read 10782 from https://www.jython.org
# 84: read 28634 from http://www.testingmcafeesites.com/index.html
# 107: read 10782 from https://www.jython.org
# 109: read 10782 from https://www.jython.org
# 88: read 28634 from http://www.testingmcafeesites.com/index.html
# 86: read 28634 from http://www.testingmcafeesites.com/index.html
# 90: read 28634 from http://www.testingmcafeesites.com/index.html
# 105: read 10782 from https://www.jython.org
# 92: read 28634 from http://www.testingmcafeesites.com/index.html
# 96: read 28634 from http://www.testingmcafeesites.com/index.html
# 94: read 28634 from http://www.testingmcafeesites.com/index.html
# 83: read 10782 from https://www.jython.org
# 98: read 28634 from http://www.testingmcafeesites.com/index.html
# 113: read 10782 from https://www.jython.org
# 111: read 10782 from https://www.jython.org
# 104: read 28634 from http://www.testingmcafeesites.com/index.html
# 100: read 28634 from http://www.testingmcafeesites.com/index.html
# 102: read 28634 from http://www.testingmcafeesites.com/index.html
# 106: read 28634 from http://www.testingmcafeesites.com/index.html
# 108: read 28634 from http://www.testingmcafeesites.com/index.html
# 115: read 10782 from https://www.jython.org
# 119: read 10782 from https://www.jython.org
# 117: read 10782 from https://www.jython.org
# 123: read 10782 from https://www.jython.org
# 121: read 10782 from https://www.jython.org
# 112: read 28634 from http://www.testingmcafeesites.com/index.html
# 114: read 28634 from http://www.testingmcafeesites.com/index.html
# 110: read 28634 from http://www.testingmcafeesites.com/index.html
# 116: read 28634 from http://www.testingmcafeesites.com/index.html125: read 10782 from https://www.jython.org
#
# 127: read 10782 from https://www.jython.org
# 131: read 10782 from https://www.jython.org
# 133: read 10782 from https://www.jython.org
# 129: read 10782 from https://www.jython.org
# 118: read 28634 from http://www.testingmcafeesites.com/index.html
# 135: read 10782 from https://www.jython.org
# 137: read 10782 from https://www.jython.org
# 124: read 28634 from http://www.testingmcafeesites.com/index.html
# 120: read 28634 from http://www.testingmcafeesites.com/index.html
# 122: read 28634 from http://www.testingmcafeesites.com/index.html
# 139: read 10782 from https://www.jython.org
# 141: read 10782 from https://www.jython.org
# 126: read 28634 from http://www.testingmcafeesites.com/index.html
# 145: read 10782 from https://www.jython.org
# 147: read 10782 from https://www.jython.org
# 143: read 10782 from https://www.jython.org
# 130: read 28634 from http://www.testingmcafeesites.com/index.html
# 128: read 28634 from http://www.testingmcafeesites.com/index.html
# 149: read 10782 from https://www.jython.org
# 134: read 28634 from http://www.testingmcafeesites.com/index.html
# 136: read 28634 from http://www.testingmcafeesites.com/index.html
# 132: read 28634 from http://www.testingmcafeesites.com/index.html
# 151: read 10782 from https://www.jython.org
# 153: read 10782 from https://www.jython.org
# 138: read 28634 from http://www.testingmcafeesites.com/index.html
# 140: read 28634 from http://www.testingmcafeesites.com/index.html
# 155: read 10782 from https://www.jython.org
# 157: read 10782 from https://www.jython.org
# 159: read 10782 from https://www.jython.org
# 144: read 28634 from http://www.testingmcafeesites.com/index.html
# 146: read 28634 from http://www.testingmcafeesites.com/index.html
# 142: read 28634 from http://www.testingmcafeesites.com/index.html
# 161: read 10782 from https://www.jython.org
# 163: read 10782 from https://www.jython.org
# 148: read 28634 from http://www.testingmcafeesites.com/index.html
# 152: read 28634 from http://www.testingmcafeesites.com/index.html
# 169: read 10782 from https://www.jython.org
# 165: read 10782 from https://www.jython.org
# 167: read 10782 from https://www.jython.org
# 150: read 28634 from http://www.testingmcafeesites.com/index.html
# 154: read 28634 from http://www.testingmcafeesites.com/index.html
# 156: read 28634 from http://www.testingmcafeesites.com/index.html
# 171: read 10782 from https://www.jython.org
# 173: read 10782 from https://www.jython.org
# 175: read 10782 from https://www.jython.org
# 158: read 28634 from http://www.testingmcafeesites.com/index.html
# 160: read 28634 from http://www.testingmcafeesites.com/index.html
# 162: read 28634 from http://www.testingmcafeesites.com/index.html
# 179: read 10782 from https://www.jython.org
# 164: read 28634 from http://www.testingmcafeesites.com/index.html
# 181: read 10782 from https://www.jython.org
# 177: read 10782 from https://www.jython.org
# 166: read 28634 from http://www.testingmcafeesites.com/index.html
# 168: read 28634 from http://www.testingmcafeesites.com/index.html
# 183: read 10782 from https://www.jython.org
# 185: read 10782 from https://www.jython.org
# 170: read 28634 from http://www.testingmcafeesites.com/index.html
# 187: read 10782 from https://www.jython.org
# 189: read 10782 from https://www.jython.org
# 191: read 10782 from https://www.jython.org
# 172: read 28634 from http://www.testingmcafeesites.com/index.html
# 174: read 28634 from http://www.testingmcafeesites.com/index.html
# 176: read 28634 from http://www.testingmcafeesites.com/index.html
# 195: read 10782 from https://www.jython.org178: read 28634 from http://www.testingmcafeesites.com/index.html
# 180: read 28634 from http://www.testingmcafeesites.com/index.html
# 193: read 10782 from https://www.jython.org
#
# 197: read 10782 from https://www.jython.org
# 182: read 28634 from http://www.testingmcafeesites.com/index.html
# 199: read 10782 from https://www.jython.org
# 201: read 10782 from https://www.jython.org
# 184: read 28634 from http://www.testingmcafeesites.com/index.html
# 186: read 28634 from http://www.testingmcafeesites.com/index.html
# 203: read 10782 from https://www.jython.org
# 188: read 28634 from http://www.testingmcafeesites.com/index.html
# 209: read 10782 from https://www.jython.org
# 190: read 28634 from http://www.testingmcafeesites.com/index.html
# 205: read 10782 from https://www.jython.org
# 192: read 28634 from http://www.testingmcafeesites.com/index.html
# 207: read 10782 from https://www.jython.org
# 194: read 28634 from http://www.testingmcafeesites.com/index.html
# 196: read 28634 from http://www.testingmcafeesites.com/index.html
# 215: read 10782 from https://www.jython.org
# 211: read 10782 from https://www.jython.org
# 213: read 10782 from https://www.jython.org
# 198: read 28634 from http://www.testingmcafeesites.com/index.html
# 200: read 28634 from http://www.testingmcafeesites.com/index.html
# 202: read 28634 from http://www.testingmcafeesites.com/index.html
# 217: read 10782 from https://www.jython.org
# 219: read 10782 from https://www.jython.org
# 204: read 28634 from http://www.testingmcafeesites.com/index.html
# 221: read 10782 from https://www.jython.org
# 208: read 28634 from http://www.testingmcafeesites.com/index.html
# 206: read 28634 from http://www.testingmcafeesites.com/index.html
# 210: read 28634 from http://www.testingmcafeesites.com/index.html
# 225: read 10782 from https://www.jython.org
# 227: read 10782 from https://www.jython.org
# 223: read 10782 from https://www.jython.org
# 229: read 10782 from https://www.jython.org
# 212: read 28634 from http://www.testingmcafeesites.com/index.html
# 214: read 28634 from http://www.testingmcafeesites.com/index.html
# 233: read 10782 from https://www.jython.org
# 216: read 28634 from http://www.testingmcafeesites.com/index.html
# 231: read 10782 from https://www.jython.org
# 218: read 28634 from http://www.testingmcafeesites.com/index.html
# 235: read 10782 from https://www.jython.org
# 220: read 28634 from http://www.testingmcafeesites.com/index.html
# 222: read 28634 from http://www.testingmcafeesites.com/index.html
# 237: read 10782 from https://www.jython.org
# 224: read 28634 from http://www.testingmcafeesites.com/index.html
# 241: read 10782 from https://www.jython.org
# 226: read 28634 from http://www.testingmcafeesites.com/index.html
# 239: read 10782 from https://www.jython.org
# 228: read 28634 from http://www.testingmcafeesites.com/index.html
# 243: read 10782 from https://www.jython.org
# 230: read 28634 from http://www.testingmcafeesites.com/index.html
# 245: read 10782 from https://www.jython.org
# 232: read 28634 from http://www.testingmcafeesites.com/index.html
# 249: read 10782 from https://www.jython.org
# 247: read 10782 from https://www.jython.org
# 251: read 10782 from https://www.jython.org
# 253: read 10782 from https://www.jython.org
# 234: read 28634 from http://www.testingmcafeesites.com/index.html
# 236: read 28634 from http://www.testingmcafeesites.com/index.html
# 255: read 10782 from https://www.jython.org
# 238: read 28634 from http://www.testingmcafeesites.com/index.html
# 257: read 10782 from https://www.jython.org
# 240: read 28634 from http://www.testingmcafeesites.com/index.html
# 259: read 10782 from https://www.jython.org
# 261: read 10782 from https://www.jython.org
# 242: read 28634 from http://www.testingmcafeesites.com/index.html
# 246: read 28634 from http://www.testingmcafeesites.com/index.html
# 244: read 28634 from http://www.testingmcafeesites.com/index.html
# 248: read 28634 from http://www.testingmcafeesites.com/index.html
# 265: read 10782 from https://www.jython.org
# 250: read 28634 from http://www.testingmcafeesites.com/index.html
# 263: read 10782 from https://www.jython.org
# 267: read 10782 from https://www.jython.org
# 252: read 28634 from http://www.testingmcafeesites.com/index.html
# 271: read 10782 from https://www.jython.org
# 256: read 28634 from http://www.testingmcafeesites.com/index.html
# 254: read 28634 from http://www.testingmcafeesites.com/index.html
# 269: read 10782 from https://www.jython.org
# 258: read 28634 from http://www.testingmcafeesites.com/index.html
# 275: read 10782 from https://www.jython.org
# 273: read 10782 from https://www.jython.org
# 260: read 28634 from http://www.testingmcafeesites.com/index.html
# 277: read 10782 from https://www.jython.org
# 262: read 28634 from http://www.testingmcafeesites.com/index.html
# 279: read 10782 from https://www.jython.org
# 264: read 28634 from http://www.testingmcafeesites.com/index.html
# 281: read 10782 from https://www.jython.org
# 283: read 10782 from https://www.jython.org
# 266: read 28634 from http://www.testingmcafeesites.com/index.html
# 270: read 28634 from http://www.testingmcafeesites.com/index.html268: read 28634 from http://www.testingmcafeesites.com/index.html
# 276: read 28634 from http://www.testingmcafeesites.com/index.html
# 278: read 28634 from http://www.testingmcafeesites.com/index.html
# 280: read 28634 from http://www.testingmcafeesites.com/index.html
# 274: read 28634 from http://www.testingmcafeesites.com/index.html
# 272: read 28634 from http://www.testingmcafeesites.com/index.html
#
# 282: read 28634 from http://www.testingmcafeesites.com/index.html
# 291: read 10782 from https://www.jython.org
# 287: read 10782 from https://www.jython.org
# 289: read 10782 from https://www.jython.org
# 285: read 10782 from https://www.jython.org
# 292: read 28634 from http://www.testingmcafeesites.com/index.html295: read 10782 from https://www.jython.org
# 294: read 28634 from http://www.testingmcafeesites.com/index.html
# 301: read 10782 from https://www.jython.org
# 290: read 28634 from http://www.testingmcafeesites.com/index.html
# 286: read 28634 from http://www.testingmcafeesites.com/index.html
# 288: read 28634 from http://www.testingmcafeesites.com/index.html
#
# 307: read 10782 from https://www.jython.org
# 299: read 10782 from https://www.jython.org
# 303: read 10782 from https://www.jython.org
# 284: read 28634 from http://www.testingmcafeesites.com/index.html
# 305: read 10782 from https://www.jython.org
# 297: read 10782 from https://www.jython.org
# 293: read 10782 from https://www.jython.org
# 304: read 28634 from http://www.testingmcafeesites.com/index.html
# 300: read 28634 from http://www.testingmcafeesites.com/index.html
# 296: read 28634 from http://www.testingmcafeesites.com/index.html
# 306: read 28634 from http://www.testingmcafeesites.com/index.html
# 302: read 28634 from http://www.testingmcafeesites.com/index.html
# 298: read 28634 from http://www.testingmcafeesites.com/index.html
# 313: read 10782 from https://www.jython.org
# 309: read 10782 from https://www.jython.org
# 315: read 10782 from https://www.jython.org
# 317: read 10782 from https://www.jython.org
# 319: read 10782 from https://www.jython.org
# 311: read 10782 from https://www.jython.org
# 321: read 10782 from https://www.jython.org
# 325: read 10782 from https://www.jython.org
# 323: read 10782 from https://www.jython.org
# 327: read 10782 from https://www.jython.org
# 329: read 10782 from https://www.jython.org
# 331: read 10782 from https://www.jython.org
# 314: read 28634 from http://www.testingmcafeesites.com/index.html
# 335: read 10782 from https://www.jython.org
# 310: read 28634 from http://www.testingmcafeesites.com/index.html
# 312: read 28634 from http://www.testingmcafeesites.com/index.html
# 333: read 10782 from https://www.jython.org
# 318: read 28634 from http://www.testingmcafeesites.com/index.html
# 308: read 28634 from http://www.testingmcafeesites.com/index.html
# 316: read 28634 from http://www.testingmcafeesites.com/index.html
# 337: read 10782 from https://www.jython.org
# 339: read 10782 from https://www.jython.org
# 320: read 28634 from http://www.testingmcafeesites.com/index.html
# 326: read 28634 from http://www.testingmcafeesites.com/index.html
# 324: read 28634 from http://www.testingmcafeesites.com/index.html
# 322: read 28634 from http://www.testingmcafeesites.com/index.html
# 328: read 28634 from http://www.testingmcafeesites.com/index.html
# 341: read 10782 from https://www.jython.org
# 343: read 10782 from https://www.jython.org
# 330: read 28634 from http://www.testingmcafeesites.com/index.html
# 332: read 28634 from http://www.testingmcafeesites.com/index.html
# 345: read 10782 from https://www.jython.org
# 347: read 10782 from https://www.jython.org
# 334: read 28634 from http://www.testingmcafeesites.com/index.html
# 349: read 10782 from https://www.jython.org
# 351: read 10782 from https://www.jython.org
# 336: read 28634 from http://www.testingmcafeesites.com/index.html
# 353: read 10782 from https://www.jython.org
# 338: read 28634 from http://www.testingmcafeesites.com/index.html
# 340: read 28634 from http://www.testingmcafeesites.com/index.html
# 357: read 10782 from https://www.jython.org
# 355: read 10782 from https://www.jython.org
# 342: read 28634 from http://www.testingmcafeesites.com/index.html
# 363: read 10782 from https://www.jython.org
# 359: read 10782 from https://www.jython.org
# 361: read 10782 from https://www.jython.org344: read 28634 from http://www.testingmcafeesites.com/index.html
#
# 365: read 10782 from https://www.jython.org
# 346: read 28634 from http://www.testingmcafeesites.com/index.html
# 369: read 10782 from https://www.jython.org
# 367: read 10782 from https://www.jython.org
# 350: read 28634 from http://www.testingmcafeesites.com/index.html
# 348: read 28634 from http://www.testingmcafeesites.com/index.html
# 352: read 28634 from http://www.testingmcafeesites.com/index.html
# 354: read 28634 from http://www.testingmcafeesites.com/index.html
# 371: read 10782 from https://www.jython.org
# 356: read 28634 from http://www.testingmcafeesites.com/index.html
# 373: read 10782 from https://www.jython.org
# 358: read 28634 from http://www.testingmcafeesites.com/index.html
# 360: read 28634 from http://www.testingmcafeesites.com/index.html
# 377: read 10782 from https://www.jython.org
# 362: read 28634 from http://www.testingmcafeesites.com/index.html
# 364: read 28634 from http://www.testingmcafeesites.com/index.html
# 366: read 28634 from http://www.testingmcafeesites.com/index.html
# 375: read 10782 from https://www.jython.org
# 381: read 10782 from https://www.jython.org
# 383: read 10782 from https://www.jython.org
# 379: read 10782 from https://www.jython.org
# 385: read 10782 from https://www.jython.org
# 368: read 28634 from http://www.testingmcafeesites.com/index.html
# 370: read 28634 from http://www.testingmcafeesites.com/index.html
# 387: read 10782 from https://www.jython.org
# 389: read 10782 from https://www.jython.org
# 372: read 28634 from http://www.testingmcafeesites.com/index.html
# 374: read 28634 from http://www.testingmcafeesites.com/index.html
# 391: read 10782 from https://www.jython.org
# 393: read 10782 from https://www.jython.org
# 378: read 28634 from http://www.testingmcafeesites.com/index.html
# 376: read 28634 from http://www.testingmcafeesites.com/index.html
# 397: read 10782 from https://www.jython.org
# 380: read 28634 from http://www.testingmcafeesites.com/index.html
# 399: read 10782 from https://www.jython.org
# 395: read 10782 from https://www.jython.org
# 382: read 28634 from http://www.testingmcafeesites.com/index.html
# 386: read 28634 from http://www.testingmcafeesites.com/index.html
# 384: read 28634 from http://www.testingmcafeesites.com/index.html
# 388: read 28634 from http://www.testingmcafeesites.com/index.html
# 390: read 28634 from http://www.testingmcafeesites.com/index.html
# 394: read 28634 from http://www.testingmcafeesites.com/index.html
# 396: read 28634 from http://www.testingmcafeesites.com/index.html
# 392: read 28634 from http://www.testingmcafeesites.com/index.html
# 398: read 28634 from http://www.testingmcafeesites.com/index.html
# Duration = 3.8141539096832275

# %% [markdown]
# Зверніть увагу на швидкість. Вона значно перевищує синхронну версію.
#
# Можна побачити, що черга виконання запитів вже не така лінійна, як у синхронній версії.
#
# Так виглядає діаграма роботи багатопотокової версії:
#
# ![діаграма роботи багтопотокової версії](media/threads.png)

# %% [markdown]
# Він використовує кілька потоків, щоб мати декілька відкритих запитів до веб-сайтів одночасно, що дозволяє програмі перекривати час очікування та швидше отримувати кінцевий результат.
#
# ##### Проблеми з threading-версією
#
# Що ж, як ви можете бачити з прикладу, для цього потрібно трохи більше коду та справді потрібно трохи подумати про те, які дані обмінюються між потоками.
#
# Потоки можуть взаємодіяти непомітно й важко для виявлення. Ці взаємодії можуть спричинити Race Conditions, які часто призводять до випадкових, періодичних помилок, які може бути досить важко знайти. Детальніше ознайомитися з концепцією Race Conditions, можна [тут](https://ru.wikipedia.org/wiki/%D0%A1%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%B3%D0%BE%D0%BD%D0%BA%D0%B8#:~:text=%D0%A1%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5%20%D0%B3%D0%BE%D0%BD%D0%BA%D0%B8%20(%D0%B0%D0%BD%D0%B3%D0%BB.,%D0%93%D0%BE%D0%BD%D0%BA%D0%B8%20%D1%81%D0%B8%D0%B3%D0%BD%D0%B0%D0%BB%D0%BE%D0%B2).).

# %% [markdown]
# #### Асинхронність: asyncio-версія.
#
# ---
#
# Згадайте кооперативну багатозадачність: головна ідея полягає у тому, щоб не переривати виконання потоку коду до того моменту, поки цей код сам не "скаже", що він готовий віддати керування (наприклад, коли цей блок коду очікує відповіді від повільного пристрою введення-виведення, мережі, тощо). Тобто, блоки коду, які ми використовуємо, повинні вміти якось взаємодіяти.
#
# Тобто, вся взаємодія, яка буде описуватись далі, не керується операційною системою, а в межах ОДНОГО потоку та одного процесу керується кодом у межах python-модуля asyncio.

# %% [markdown]
# ##### Основи __asyncio__. Як це працює.
#
# Загальна концепція asyncio полягає у тому, що єдиний об’єкт Python, який називається цикл подій, контролює як та коли виконується кожне завдання. Цикл подій знає про кожне завдання та знає, у якому стані воно перебуває. Насправді, існує багато станів, у яких можуть перебувати завдання, але зараз уявімо спрощений цикл подій, який має лише два стани.
#
# __Стан готовності__ вказуватиме на те, що завдання має виконати роботу та готове до виконання, а __стан очікування__ означає, що завдання очікує завершення зовнішньої дії, наприклад мережевої операції.
#
# Ваш спрощений цикл подій підтримує два списки завдань, по одному для кожного з цих станів. Він обирає одне з готових завдань (__стан готовності__) та "дає йому роботу". Це завдання знаходиться працює самостійно та його робота не буде перериватись доки воно самостійно не передасть керування назад у цикл подій.
#
# Коли запущене завдання повертає керування циклу подій, цикл подій розміщує це завдання або у __списку готовності__, або у __списку очікування__ (в залежності від того, повернуті результати роботи, чи ні), а потім переглядає кожне завдання у __списку очікування__, щоб перевірити, чи воно стало готовим до завершення, тобто завершилася операція введення-виведення, чи ні. Він знає, що завдання у __списку готовності__ все ще готові отримувати завдання, оскільки вони ще не запущені.
#
# Коли усі завдання знову відсортовано в правильному списку, цикл подій обирає наступне завдання для запуску та процес повторюється. Ваш спрощений цикл подій вибирає завдання, яке чекало найдовше та запускає його. Цей процес повторюється до завершення циклу подій.
#
# Важливим моментом asyncio є те, що завдання ніколи не відмовляються від контролю без свідомості. Їх ніколи не переривають під час операції. Це дозволяє нам трохи легше ділитися ресурсами в asyncio ніж у threading. Не потрібно турбуватися про те, щоб зробити ваш код потокобезпечним.
#
# Це досить високорівневий погляд на роботу asyncio. Докладніше дивіться [тут](https://stackoverflow.com/questions/49005651/how-does-asyncio-actually-work/51116910#51116910) або в [документації](https://docs.python.org/3/library/asyncio.html).

# %% [markdown]
# ##### async та await
#
# Два нових ключових слова, доданих до Python, починаючи з версії 3.5: __async__ та __await__.
#
# ###### await
#
# Можна розглядати await як оператор або команду, яка дозволяє завданню передати керування назад у цикл подій. Коли ваш код очікує щось (відповідь з мережі, відповідь від якогось пристрою введення-виведення), це означає, що виклик, ймовірно, буде чимось, що займе деякий час й завдання має відмовитися від контролю.
#
# ###### async
#
# Найлегше уявити async Python як прапорець, який повідомляє, що функція, яку потрібно визначити, використовує await. У деяких випадках це не зовсім вірно, як асинхронні генератори, але це актуально для багатьох випадків та надає просту модель, поки ви починаєте.
#
# Одним винятком з цього, який ви побачите у наступному коді, є async with оператор, який створює диспетчер контексту з об’єкта, якого ви зазвичай очікуєте. Хоча семантика дещо інша, ідея та сама: позначити цей контекстний менеджер як щось, що можна замінити.
#
# ##### Асинхронна версія коду.

# %%
import asyncio
import time
import aiohttp
import functools


def get_duration(func):
    @functools.wraps(func)
    def wraper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        duration = time.time() - start_time
        print(f"Duration = {duration}")
        return res

    return wraper


async def download_site(session, url, num):
    async with session.get(url) as response:
        print(
            f"Read -{num}- {response.content_length} from {url}, status code is {response.status}"
        )


async def download_all_sites(sites):
    async with aiohttp.ClientSession() as session:
        tasks = [
            asyncio.create_task(download_site(session, url, num)) for num, url in enumerate(sites)
        ]
        await asyncio.gather(*tasks)


sites = [
            "http://www.testingmcafeesites.com/index.html",
            "https://www.jython.org"
        ] * 200

if __name__ == "__main__":
    asyncio.set_event_loop_policy(asyncio.WindowsSelectorEventLoopPolicy())
    start_time = time.time()
    await download_all_sites(sites)
    duration = time.time() - start_time
    print(f"Duration = {duration}")
# Out:
# Read -12- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -16- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -0- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -32- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -54- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -18- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -50- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -10- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -30- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -24- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -3- 3721 from https://www.jython.org, status code is 200
# Read -62- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -41- 3721 from https://www.jython.org, status code is 200
# Read -28- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -58- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -14- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -64- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -19- 3721 from https://www.jython.org, status code is 200
# Read -22- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -70- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -1- 3721 from https://www.jython.org, status code is 200
# Read -60- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -5- 3721 from https://www.jython.org, status code is 200
# Read -20- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -4- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -11- 3721 from https://www.jython.org, status code is 200
# Read -2- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -8- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -26- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -56- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -6- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -7- 3721 from https://www.jython.org, status code is 200
# Read -78- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -92- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -29- 3721 from https://www.jython.org, status code is 200
# Read -66- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -82- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -88- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -52- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -17- 3721 from https://www.jython.org, status code is 200
# Read -21- 3721 from https://www.jython.org, status code is 200
# Read -84- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -76- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -74- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -94- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -86- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -72- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -25- 3721 from https://www.jython.org, status code is 200
# Read -15- 3721 from https://www.jython.org, status code is 200
# Read -80- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -35- 3721 from https://www.jython.org, status code is 200
# Read -68- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -23- 3721 from https://www.jython.org, status code is 200
# Read -96- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -33- 3721 from https://www.jython.org, status code is 200
# Read -90- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -98- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -47- 3721 from https://www.jython.org, status code is 200
# Read -63- 3721 from https://www.jython.org, status code is 200
# Read -73- 3721 from https://www.jython.org, status code is 200
# Read -53- 3721 from https://www.jython.org, status code is 200
# Read -13- 3721 from https://www.jython.org, status code is 200
# Read -31- 3721 from https://www.jython.org, status code is 200
# Read -67- 3721 from https://www.jython.org, status code is 200
# Read -27- 3721 from https://www.jython.org, status code is 200
# Read -75- 3721 from https://www.jython.org, status code is 200
# Read -51- 3721 from https://www.jython.org, status code is 200
# Read -45- 3721 from https://www.jython.org, status code is 200
# Read -57- 3721 from https://www.jython.org, status code is 200
# Read -37- 3721 from https://www.jython.org, status code is 200
# Read -59- 3721 from https://www.jython.org, status code is 200
# Read -65- 3721 from https://www.jython.org, status code is 200
# Read -69- 3721 from https://www.jython.org, status code is 200
# Read -77- 3721 from https://www.jython.org, status code is 200
# Read -49- 3721 from https://www.jython.org, status code is 200
# Read -61- 3721 from https://www.jython.org, status code is 200
# Read -71- 3721 from https://www.jython.org, status code is 200
# Read -79- 3721 from https://www.jython.org, status code is 200
# Read -9- 3721 from https://www.jython.org, status code is 200
# Read -43- 3721 from https://www.jython.org, status code is 200
# Read -39- 3721 from https://www.jython.org, status code is 200
# Read -101- 3721 from https://www.jython.org, status code is 200
# Read -55- 3721 from https://www.jython.org, status code is 200
# Read -107- 3721 from https://www.jython.org, status code is 200
# Read -105- 3721 from https://www.jython.org, status code is 200
# Read -103- 3721 from https://www.jython.org, status code is 200
# Read -113- 3721 from https://www.jython.org, status code is 200
# Read -111- 3721 from https://www.jython.org, status code is 200
# Read -109- 3721 from https://www.jython.org, status code is 200
# Read -139- 3721 from https://www.jython.org, status code is 200
# Read -137- 3721 from https://www.jython.org, status code is 200
# Read -147- 3721 from https://www.jython.org, status code is 200
# Read -135- 3721 from https://www.jython.org, status code is 200
# Read -143- 3721 from https://www.jython.org, status code is 200
# Read -133- 3721 from https://www.jython.org, status code is 200
# Read -141- 3721 from https://www.jython.org, status code is 200
# Read -145- 3721 from https://www.jython.org, status code is 200
# Read -165- 3721 from https://www.jython.org, status code is 200
# Read -177- 3721 from https://www.jython.org, status code is 200
# Read -185- 3721 from https://www.jython.org, status code is 200
# Read -181- 3721 from https://www.jython.org, status code is 200
# Read -167- 3721 from https://www.jython.org, status code is 200
# Read -169- 3721 from https://www.jython.org, status code is 200
# Read -175- 3721 from https://www.jython.org, status code is 200
# Read -106- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -102- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -173- 3721 from https://www.jython.org, status code is 200
# Read -171- 3721 from https://www.jython.org, status code is 200
# Read -100- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -183- 3721 from https://www.jython.org, status code is 200
# Read -179- 3721 from https://www.jython.org, status code is 200
# Read -110- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -104- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -114- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -112- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -108- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -191- 3721 from https://www.jython.org, status code is 200
# Read -116- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -128- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -124- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -120- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -122- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -118- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -189- 3721 from https://www.jython.org, status code is 200
# Read -187- 3721 from https://www.jython.org, status code is 200
# Read -130- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -140- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -132- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -197- 3721 from https://www.jython.org, status code is 200
# Read -126- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -138- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -142- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -136- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -195- 3721 from https://www.jython.org, status code is 200
# Read -201- 3721 from https://www.jython.org, status code is 200
# Read -134- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -193- 3721 from https://www.jython.org, status code is 200
# Read -199- 3721 from https://www.jython.org, status code is 200
# Read -205- 3721 from https://www.jython.org, status code is 200
# Read -148- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -146- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -207- 3721 from https://www.jython.org, status code is 200
# Read -203- 3721 from https://www.jython.org, status code is 200
# Read -144- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -160- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -150- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -176- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -174- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -209- 3721 from https://www.jython.org, status code is 200
# Read -168- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -211- 3721 from https://www.jython.org, status code is 200
# Read -164- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -34- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -182- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -180- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -162- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -178- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -38- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -46- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -40- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -158- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -172- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -170- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -154- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -156- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -166- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -48- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -152- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -95- 3721 from https://www.jython.org, status code is 200
# Read -42- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -44- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -36- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -83- 3721 from https://www.jython.org, status code is 200
# Read -219- 3721 from https://www.jython.org, status code is 200
# Read -85- 3721 from https://www.jython.org, status code is 200
# Read -227- 3721 from https://www.jython.org, status code is 200
# Read -87- 3721 from https://www.jython.org, status code is 200
# Read -89- 3721 from https://www.jython.org, status code is 200
# Read -200- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -217- 3721 from https://www.jython.org, status code is 200
# Read -204- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -221- 3721 from https://www.jython.org, status code is 200
# Read -231- 3721 from https://www.jython.org, status code is 200
# Read -229- 3721 from https://www.jython.org, status code is 200
# Read -213- 3721 from https://www.jython.org, status code is 200
# Read -202- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -99- 3721 from https://www.jython.org, status code is 200
# Read -257- 3721 from https://www.jython.org, status code is 200
# Read -245- 3721 from https://www.jython.org, status code is 200
# Read -249- 3721 from https://www.jython.org, status code is 200
# Read -215- 3721 from https://www.jython.org, status code is 200
# Read -225- 3721 from https://www.jython.org, status code is 200
# Read -97- 3721 from https://www.jython.org, status code is 200
# Read -237- 3721 from https://www.jython.org, status code is 200
# Read -251- 3721 from https://www.jython.org, status code is 200
# Read -241- 3721 from https://www.jython.org, status code is 200
# Read -223- 3721 from https://www.jython.org, status code is 200
# Read -119- 3721 from https://www.jython.org, status code is 200
# Read -259- 3721 from https://www.jython.org, status code is 200
# Read -206- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -212- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -93- 3721 from https://www.jython.org, status code is 200
# Read -247- 3721 from https://www.jython.org, status code is 200
# Read -235- 3721 from https://www.jython.org, status code is 200
# Read -239- 3721 from https://www.jython.org, status code is 200
# Read -255- 3721 from https://www.jython.org, status code is 200
# Read -81- 3721 from https://www.jython.org, status code is 200
# Read -91- 3721 from https://www.jython.org, status code is 200
# Read -233- 3721 from https://www.jython.org, status code is 200
# Read -243- 3721 from https://www.jython.org, status code is 200
# Read -253- 3721 from https://www.jython.org, status code is 200
# Read -153- 3721 from https://www.jython.org, status code is 200
# Read -123- 3721 from https://www.jython.org, status code is 200
# Read -265- 3721 from https://www.jython.org, status code is 200
# Read -273- 3721 from https://www.jython.org, status code is 200
# Read -115- 3721 from https://www.jython.org, status code is 200
# Read -151- 3721 from https://www.jython.org, status code is 200
# Read -267- 3721 from https://www.jython.org, status code is 200
# Read -159- 3721 from https://www.jython.org, status code is 200
# Read -117- 3721 from https://www.jython.org, status code is 200
# Read -131- 3721 from https://www.jython.org, status code is 200
# Read -149- 3721 from https://www.jython.org, status code is 200
# Read -224- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -277- 3721 from https://www.jython.org, status code is 200
# Read -214- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -157- 3721 from https://www.jython.org, status code is 200
# Read -222- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -218- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -220- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -275- 3721 from https://www.jython.org, status code is 200
# Read -261- 3721 from https://www.jython.org, status code is 200
# Read -125- 3721 from https://www.jython.org, status code is 200
# Read -271- 3721 from https://www.jython.org, status code is 200
# Read -269- 3721 from https://www.jython.org, status code is 200
# Read -127- 3721 from https://www.jython.org, status code is 200
# Read -216- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -155- 3721 from https://www.jython.org, status code is 200
# Read -228- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -129- 3721 from https://www.jython.org, status code is 200
# Read -226- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -161- 3721 from https://www.jython.org, status code is 200
# Read -234- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -238- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -263- 3721 from https://www.jython.org, status code is 200
# Read -163- 3721 from https://www.jython.org, status code is 200
# Read -232- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -297- 3721 from https://www.jython.org, status code is 200
# Read -121- 3721 from https://www.jython.org, status code is 200
# Read -291- 3721 from https://www.jython.org, status code is 200
# Read -295- 3721 from https://www.jython.org, status code is 200
# Read -293- 3721 from https://www.jython.org, status code is 200
# Read -230- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -289- 3721 from https://www.jython.org, status code is 200
# Read -236- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -240- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -299- 3721 from https://www.jython.org, status code is 200
# Read -303- 3721 from https://www.jython.org, status code is 200
# Read -301- 3721 from https://www.jython.org, status code is 200
# Read -190- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -184- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -188- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -254- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -252- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -250- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -327- 3721 from https://www.jython.org, status code is 200
# Read -329- 3721 from https://www.jython.org, status code is 200
# Read -325- 3721 from https://www.jython.org, status code is 200
# Read -323- 3721 from https://www.jython.org, status code is 200
# Read -321- 3721 from https://www.jython.org, status code is 200
# Read -319- 3721 from https://www.jython.org, status code is 200
# Read -317- 3721 from https://www.jython.org, status code is 200
# Read -339- 3721 from https://www.jython.org, status code is 200
# Read -248- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -315- 3721 from https://www.jython.org, status code is 200
# Read -246- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -244- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -313- 3721 from https://www.jython.org, status code is 200
# Read -311- 3721 from https://www.jython.org, status code is 200
# Read -242- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -309- 3721 from https://www.jython.org, status code is 200
# Read -307- 3721 from https://www.jython.org, status code is 200
# Read -305- 3721 from https://www.jython.org, status code is 200
# Read -186- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -355- 3721 from https://www.jython.org, status code is 200
# Read -353- 3721 from https://www.jython.org, status code is 200
# Read -351- 3721 from https://www.jython.org, status code is 200
# Read -349- 3721 from https://www.jython.org, status code is 200
# Read -347- 3721 from https://www.jython.org, status code is 200
# Read -345- 3721 from https://www.jython.org, status code is 200
# Read -343- 3721 from https://www.jython.org, status code is 200
# Read -341- 3721 from https://www.jython.org, status code is 200
# Read -335- 3721 from https://www.jython.org, status code is 200
# Read -337- 3721 from https://www.jython.org, status code is 200
# Read -333- 3721 from https://www.jython.org, status code is 200
# Read -331- 3721 from https://www.jython.org, status code is 200
# Read -363- 3721 from https://www.jython.org, status code is 200
# Read -258- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -359- 3721 from https://www.jython.org, status code is 200
# Read -361- 3721 from https://www.jython.org, status code is 200
# Read -357- 3721 from https://www.jython.org, status code is 200
# Read -371- 3721 from https://www.jython.org, status code is 200
# Read -369- 3721 from https://www.jython.org, status code is 200
# Read -256- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -367- 3721 from https://www.jython.org, status code is 200
# Read -365- 3721 from https://www.jython.org, status code is 200
# Read -268- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -266- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -260- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -264- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -262- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -288- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -290- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -286- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -282- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -284- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -278- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -280- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -292- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -377- 3721 from https://www.jython.org, status code is 200
# Read -276- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -274- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -375- 3721 from https://www.jython.org, status code is 200
# Read -272- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -270- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -373- 3721 from https://www.jython.org, status code is 200
# Read -294- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -399- 3721 from https://www.jython.org, status code is 200
# Read -397- 3721 from https://www.jython.org, status code is 200
# Read -395- 3721 from https://www.jython.org, status code is 200
# Read -391- 3721 from https://www.jython.org, status code is 200
# Read -393- 3721 from https://www.jython.org, status code is 200
# Read -387- 3721 from https://www.jython.org, status code is 200
# Read -385- 3721 from https://www.jython.org, status code is 200
# Read -383- 3721 from https://www.jython.org, status code is 200
# Read -381- 3721 from https://www.jython.org, status code is 200
# Read -296- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -298- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -379- 3721 from https://www.jython.org, status code is 200
# Read -304- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -302- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -308- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -389- 3721 from https://www.jython.org, status code is 200
# Read -310- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -300- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -306- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -192- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -198- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -210- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -196- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -194- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -328- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -326- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -324- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -318- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -322- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -279- 3721 from https://www.jython.org, status code is 200
# Read -330- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -336- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -320- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -334- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -314- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -312- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -208- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -316- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -332- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -283- 3721 from https://www.jython.org, status code is 200
# Read -287- 3721 from https://www.jython.org, status code is 200
# Read -338- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -340- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -344- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -348- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -342- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -350- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -346- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -356- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -358- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -352- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -354- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -281- 3721 from https://www.jython.org, status code is 200
# Read -394- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -398- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -392- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -390- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -396- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -285- 3721 from https://www.jython.org, status code is 200
# Read -362- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -360- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -364- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -368- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -376- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -366- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -378- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -382- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -370- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -372- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -386- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -374- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -384- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -380- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Read -388- 2335 from http://www.testingmcafeesites.com/index.html, status code is 200
# Duration = 3.450202226638794

# %% [markdown]
# ---
#
# ### ВАЖЛИВО!!
#
# Зважаючи на [особливості виконання асинхронного коду в CPython та у середовищі jupyter notebook](https://stackoverflow.com/questions/55409641/asyncio-run-cannot-be-called-from-a-running-event-loop-when-using-jupyter-no), для демонстрації роботи цього блоку документа доцільніше запустити його у файлі __async_version.py__, який знаходиться у цій же теці.
#
# ---

# %% [markdown]
# Ця версія трохи складніша за дві попередні. Вона має подібну структуру, але з налаштуванням завдань потрібно трохи більше роботи, ніж зі створенням ThreadPoolExecutor. Почнемо з верхньої частини прикладу.
#
# __download_site()__
#
# Функція download_site() у верхній частині майже ідентична threading версії, за винятком async ключового слова у рядку визначення функції та async with ключових слів під час виклику session.get(). Пізніше ви побачите, чому Session можна передати сюди, а не використовувати локальне сховище потоків.
#
# __download_all_sites()__
#
# У функції download_all_sites() ви побачите найбільшу зміну з threading прикладу.
#
# Можете поділитися сеансом між усіма завданнями, тому сеанс створюється тут як менеджер контексту. Завдання можуть спільно використовувати сеанс, оскільки всі вони виконуються в одному потоці. Немає способу, яким одне завдання може перервати інше, поки сеанс перебуває у "поганому" стані, тобто у стані несподіване переривання, у якому може мати негативні наслідки.
#
# У цьому контекстному менеджері with створює список завдань за допомогою asyncio.ensure_future(), що піклується про їх запуск. Після створення всіх завдань ця функція використовує asyncio.gather() для підтримки контексту сеансу, доки всі завдання не будуть завершені.
#
# Код threading робить щось подібне до цього, але деталі зручно обробляти у ThreadPoolExecutor. Наразі AsyncioPoolExecutor класу немає.
#
# Однак тут є одна невелика, але важлива зміна, прихована у деталях. Пам’ятаєте, як ми говорили про кількість потоків для створення? У threading прикладі не було очевидно, яка оптимальна кількість потоків.
#
# Однією з чудових переваг asyncio є те, що модуль масштабується набагато краще, ніж threading. Створення кожного завдання займає набагато менше ресурсів та менше часу, ніж створення потоку, тому створення та виконання більшої кількості завдань працює добре. Цей приклад просто створює окреме завдання для кожного сайту для завантаження, що працює досить добре.
#
# Зверніть увагу, що запуск коду у jupyter notebook та в окремоу файлі (__async_version.py__) відрізняється. Це обумовлено технічними особливостями двох, фактично, різних оболонок виконання.
#
# ###### Чим крута asyncio версія?
#
# Це дуже швидко! Це, напевно, найшвидший варіант.
#
# Часова діаграма виконання виглядає дуже подібно до того, що відбувається в threading прикладі. Просто всі запити введення/виведення виконуються одним потоком:

# %% [markdown]
# ![diagramm for asyncio version](media/async_task.png)

# %% [markdown]
# Відсутність такої гарної обгортки ThreadPoolExecutor робить цей код дещо складнішим, ніж threading приклад. Це той випадок, коли вам доведеться трохи попрацювати, щоб отримати набагато кращу продуктивність.
#
# Крім того, існує загальний аргумент, що необхідність додавати async та await у належних місцях є додатковою складністю. Певною мірою це істина. Зворотний бік цього аргументу полягає в тому, що він змушує вас думати про те, коли дане завдання буде замінено, що може допомогти вам створити кращий та швидший дизайн.

# %% [markdown]
# ###### Проблеми з asyncio версією
#
# __asyncio__
#  На цьому етапі є кілька проблем. Вам потрібні спеціальні асинхронні версії бібліотек, щоб отримати всі переваги asyncio. Якби ви використовували лише requests для завантаження сайтів, це було б набагато повільніше, оскільки requests не призначено для сповіщення циклу подій про те, що його заблоковано. Ця проблема стає все меншою й меншою з часом та все більше бібліотек охоплює asyncio.
#
# Інша, більш тонка проблема полягає у тому, що всі переваги кооперативної багатозадачності втрачаються, якщо одне з завдань не співпрацює. Незначна помилка у коді може призвести до вимкнення завдання та затримки процесора протягом тривалого часу, заважаючи іншим завданням, які потребують виконання. Немає можливості увійти до циклу подій, якщо завдання не передасть йому керування.

# %% [markdown]
# ##### Багатопроцесорна версія коду.
#
# ---
#
# На відміну від попередніх підходів, multiprocessing версія коду повністю використовує переваги кількох ЦП, які має ваш крутий новий комп’ютер. Почнемо з коду:

# %%
import requests
import multiprocessing
import time

session = None


def get_duration(func):
    @functools.wraps(func)
    def wraper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        duration = time.time() - start_time
        print(f"Duration = {duration}")
        return res

    return wraper


def set_global_session():
    global session
    if not session:
        session = requests.Session()


def download_site(url):
    with session.get(url) as response:
        name = multiprocessing.current_process().name
        print(f"{name}:Read {len(response.content)} from {url}")


def download_all_sites(sites):
    with multiprocessing.Pool(initializer=set_global_session) as pool:
        pool.map(download_site, sites)

# %% [markdown]
# ##  ВАЖЛИВО!
#
# Розберемо код, а запускати його необхідно в окремому файлі (знаходиться у цій же теці, має назву __multi.py__). Це пов'язано з взаємодією IPython, який використовує jupyter notebook та взаємодією з Windows. Докладніше [тут](https://medium.com/@grvsinghal/speed-up-your-python-code-using-multiprocessing-on-windows-and-jupyter-or-ipython-2714b49d6fac).
#
# Так як ускланювати код при поясненні основ не сама гарна ідея, дивимось код тут, а запускаємо такий самий код в окремому файлі.

# %% [markdown]
# ###### __multiprocessing код__
#
# У коді є кілька невеликих змін порівняно з нашою синхронною версією.
# Перший у функції download_all_sites(). Замість того, щоб просто викликати download_site() кілька разів, він створює multiprocessing.Pool об’єкт та мапить download_site на iterable sites. Це має виглядати знайомим з threading прикладу.
#
# Тут відбувається те, що Pool створює кілька окремих процесів інтерпретатора Python та кожен з них запускає вказану функцію для деяких елементів ітерованого елемента, яким у нашому випадку є список сайтів. Зв’язок між головним процесом та іншими процесами обробляється multiprocessing модулем за вас.
#
# Рядок, який створює Pool, варта вашої уваги. По-перше, він не вказує, скільки процесів потрібно створити в Pool, хоча це необов’язковий параметр. За замовчуванням multiprocessing.Pool() визначатиме кількість ЦП у вашому комп’ютері та відповідатиме їй. Найчастіше це найкраща відповідь та це у даному випадку.
#
# Для цієї проблеми збільшення кількості процесів не пришвидшило роботу. Це фактично уповільнило роботу, оскільки вартість налаштування та зняття всіх цих процесів була більшою, ніж перевага від виконання запитів введення-виведення паралельно.
#
# Далі ми маємо initializer=set_global_session частину цього виклику. Пам’ятайте, що кожен наш процес Pool має власний простір пам’яті. Це означає, що вони не можуть ділитися такими речами, як Session об’єкт. Ви не хочете створювати нову Session щоразу, коли викликається функція, ви хочете створити по одній для кожного процесу.
#
# Параметр initializer функції створено саме для цього випадку. Немає способу передати значення, що повертається, назад з initializer функції, яку викликає функція download_site(), але ви можете ініціалізувати глобальну session змінну, щоб утримувати один сеанс для кожного процесу. Оскільки кожен процес має власний простір пам’яті, глобальний для кожного буде різним.
#
# Це насправді все. Решта коду дуже схожа на те, що ви бачили раніше.

# %% [markdown]
# ##### Чому multiprocessing версія крута.
#
# Версія multiprocessing цього прикладу чудова, тому що її відносно легко налаштувати та вимагає невеликого додаткового коду. Він також повністю використовує потужність ЦП вашого комп’ютера. Часова діаграма виконання цього коду виглядає так:

# %% [markdown]
# ![multiprocessing IO diagramm](media/multiprocessing.png)

# %% [markdown]
# ##### Проблеми з multiprocessing версією
#
# Ця версія прикладу вимагає додаткового налаштування, а глобальний session об’єкт є дивним. Ви повинні витратити деякий час на роздуми про те, які змінні будуть доступні в кожному процесі.
#
# Нарешті, він явно повільніший, ніж версії з залученням модулів asyncio та threading, тому що вимагає надвеликих накладних витрат: фактично на кожному вашому процесорі було запущено окремий інтерпретатор Python!
#
# Це не дивно, оскільки проблеми, пов’язані з введенням/виведенням, насправді не multiprocessing рішень.

# %% [markdown]
# #### CPU-bound завдання
#
# ---
#
# Трохи змінимо напрямок думок. Усі приклади досі стосувалися проблеми, пов’язаної з введенням-виведенням. Розглянемо проблему, пов’язану з процесором. Як ви бачили, проблема, пов’язана з введенням-виведенням, витрачає більшу частину часу на очікування завершення зовнішніх операцій, наприклад мережевого виклику. Проблема, пов’язана з процесором, з іншого боку, виконує мало операцій введення-виведення та її загальний час виконання є фактором того, наскільки швидко вона може обробити необхідні дані.
#
# Для цілей нашого прикладу ми використаємо дещо функцію що потребує багато часу для виконання на ЦП. Ця функція отримує цілі числа в ітераційному об’єкті, знаходить для них усі існуючі цілі дільники, які повертає у списках, розміщених у кортежі (послідовність результатів відповідає послідовності початкових чисел в аргументі функції).
# Зверніть увагу, що функція використовує найбільш неефективний алгоритм пошуку цілочисельного дільника. Завдання цієї програми полягає у дослідженні ефективності багатопроцесорної обробки з "CPU-bound" кодом.

# %%
def factorize_singl(*number) -> tuple:
    # gets integers in an iterable object, finds for them all existing integer divisors
    # which it returns in the lists placed in a tuple (the sequence of results corresponds
    # to the sequence of initial numbers in the function argument)
    # Important! The function uses the most inefficient integer divisor search algorithm.
    # The task of this program is to investigate the efficiency of multiprocessing with
    # "CPU-bound" code.
    return tuple([x for x in range(1, num + 1) if num % x == 0] for num in number)

# %% [markdown]
# Для того, щоб порівняти різні підходи для такого класу завдань розмістимо цю функцію, а також її багатопроцесорні варіанти (з різними варіантами запуску багатопроцесорних завдань) у файлі __multiprocess.py__ у цій же теці. Запустіть програму, почекайте декілька хвилин, щоб дочекатись результатів, а потім зробимо висновки.
#
# Як працює синхронна версія? Діаграма її роботи:

# %% [markdown]
# ![робота синхронної версії](media/CPU_bound_task.png)

# %% [markdown]
# На відміну від прикладів, пов’язаних з введенням/виведенням, приклади, пов’язані з процесором, зазвичай досить послідовні у часі виконання.
#
# Як працюють multiprocessing версії програм. Діаграма їх роботи:

# %% [markdown]
# ![робота в багатопроцесорному режимі](media/multiprocessing_work.png)

# %% [markdown]
# Діаграма зроблена для роботи двох процесорів. Коли використовується більше процесорів з'являються додаткові, абсолютно аналогічні процеси (у прикладі в файлі - до 8-и процесів).
#
# Порівнюючи роботу, швидкість суттєво збільшується при збільшенні кількості процесів, але не лінійно, бо додаткові затрати виробничих потужностей при фактичних запусках додаткових інтерпретаторів будуть досить значними. Але інших шляхів підвищити швидкість обробки такого класу завдань немає.

# %% [markdown]
# ##### threading та asyncio версії

# %% [markdown]
# Як ви гадаєте, наскільки це пришвидшить переписування цього коду за допомогою threading або asyncio?
#
# Якщо ви відповіли «Зовсім ні» — ви молодець та вірно зрозуміли тему. Якщо ви відповіли: «Це сповільнить роботу» — ви двічі молодець, бо це й є вірна відповідь.
#
# Ось чому: у вашому прикладі, пов’язаному з введенням-виведенням вище, більша частина загального часу була витрачена на очікування завершення повільних операцій. Модулі threading та asyncio пришвидшили це, дозволивши вам перекривати час очікування замість того, щоб виконувати їх послідовно.
#
# Проте, якщо проблема пов’язана з процесором, чекати не потрібно. ЦП запускає так швидко, як тільки може, щоб вирішити проблему. У Python потоки та завдання виконуються на одному процесорі в одному процесі. Це означає, що один центральний процесор виконує усю роботу неконкурентного коду, а також додаткову роботу з налаштування потоків або завдань.

# %% [markdown]
# ##### Чому multiprocessing версія крута?
#
# Версія multiprocessing цього прикладу чудова, тому що її відносно легко налаштувати та вимагає невеликого додаткового коду. Вона також повністю використовує потужність ЦП вашого комп’ютера.
#
# Це саме те, що ми казали минулого разу, коли ми дивилися на multiprocessing при IO-bound завданні. Велика різниця полягає в тому, що цього разу це фактично найкращий варіант.
#
# ##### Проблеми з __multiprocessing__ версією.
#
# Є деякі недоліки використання multiprocessing. Вони насправді не відображаються у цьому простому прикладі, але розділити вашу проблему, щоб кожен процесор міг працювати незалежно, іноді може бути важко.
#
# Крім того, багато рішень вимагають більше зв’язку між процесами. Це може додати певної складності вашому рішенню, з яким не потрібно мати справу неконкурентній програмі.
